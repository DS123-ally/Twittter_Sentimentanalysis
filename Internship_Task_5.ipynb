# %% [markdown]
# <a href="https://colab.research.google.com/github/DS123-ally/Twittter_Sentimentanalysis/blob/main/Internship_Task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/twitter_training.csv", header=None, names=['ID', 'Game', 'Sentiment', 'Tweet'])

# %%
df
# Out:
#          ID         Game Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                    Tweet
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
# Remove rows with missing tweet text
df_cleaned = df.dropna(subset=["Tweet"])

# Remove duplicate rows
df_cleaned = df_cleaned.drop_duplicates
print("Cleaned dataset shape:", df_cleaned.shape)
# Out:
# Cleaned dataset shape: (71656, 4)

# %%
df.shape
# Out:
# (74682, 4)

# %%
df
# Out:
#          ID         Game Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                    Tweet
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from  wordcloud import WordCloud

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Sentiment",data=df_cleaned,color="red")
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
top_topics=df_cleaned["Game"].value_counts().head(10)
print(top_topics)
# Out:
# Game
# TomClancysRainbowSix    2328
# Verizon                 2319
# MaddenNFL               2315
# CallOfDuty              2314
# Microsoft               2304
# WorldOfCraft            2300
# NBA2K                   2299
# LeagueOfLegends         2296
# TomClancysGhostRecon    2291
# Facebook                2289
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Game", data=df_cleaned, color="yellow", order=top_topics.index)
plt.title("Top 10 Games")
plt.ylabel("Game")
plt.xlabel("Tweet Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
